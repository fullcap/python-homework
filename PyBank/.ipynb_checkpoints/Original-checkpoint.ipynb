# %%
#The total number of months included in the dataset.
#The net total amount of Profit/Losses over the entire period.
#The average of the changes in Profit/Losses over the entire period.
#The greatest increase in profits (date and amount) over the entire period.
#The greatest decrease in losses (date and amount) over the entire period.
import os
import csv
import pandas as pd

csvpath = os.path.join('budget_data.csv')


# general varables
prev_day = None
curr_day = None
prev_price = None
curr_price = None
change = int()

total_mths = int()
total = int()
avg_chg = int()
increase = int()
decrease = int()

change_trkr = []
# varables for greatest increase
pnl_trkr = []
win_increase_trkr = []
win_increase_date_trkr_dict = {}
win_dates = []
win_increases = []
win_dates_index = -1
win_increases_index = -1


loss_decrease_trkr = []
loss_decrease_date_trkr_dict = {}
loss_dates = []
loss_decreases = []
loss_dates_index = -1
loss_decreases_index = -1

curr_day_pnl = int()
prev_day_pnl = int()

with open(csvpath, newline="") as csvfile:
    csvreader = csv.reader(csvfile, delimiter=",")
        
    csv_header = next(csvreader)
    for row in csvreader:
        #calculate total months
        total_mths += 1
        
        #calculate net total pnl
        total += int(row[1])


        if prev_day == None and curr_day == None:
            prev_day = int(row[1])
            curr_day = int(row[1])
        else:
            if prev_day == curr_day and curr_day is not int(row[1]):
                curr_day = int(row[1])
            else:
                if prev_day > curr_day:
                    curr_loss = prev_day - curr_day
                else:
                    cur_win = curr_day - prev_day
                    
        # greatest increase algo           
        #transition from none to first day
        if str(prev_day_pnl) == 'None' and str(curr_day) == 'None':
            prev_day_pnl = row[1]
            curr_day_pnl = row[1]
            #print('transition from none to first day:prev_day_pnl = row[1] == ' + row[1])
            #print('transition from none to first day: curr_day_pnl = row[1] == ' + row[1])
            
        #transition from first day to second day
        if prev_day_pnl == curr_day_pnl:
            curr_day_pnl = row[1]
            pnl_trkr.append((row[1]))
            #print('transition from first day to second day: prev_day_pnl = ',prev_day_pnl)
            #print('transition from first day to second day: curr_day_pnl = ',curr_day_pnl)

        # loop through the rest of days
        if prev_day_pnl != curr_day_pnl and curr_day_pnl != row[1]:
            prev_day_pnl = curr_day_pnl
            curr_day_pnl = row[1]
            pnl_trkr.append((row[1]))
            #print('prev_day_pnl = ',prev_day_pnl)
            #print('curr_day_pnl = ',curr_day_pnl)    
        
        #id losing days
        if int(curr_day_pnl) < 0: # Losing Day
            
            
            
            if int(prev_day_pnl) > 0 and int(curr_day_pnl) < 0: #prev_day_pnl = losing day & curr_day_pnl = Winning day
                curr_date = row[0]
                loss_decrease_trkr.append(curr_date)
                
                loss_decrease = int(curr_day_pnl) + -(int((prev_day_pnl)))
                loss_decrease_trkr.append(loss_decrease)
                
                loss_decrease_date_trkr_dict[curr_date] = loss_decrease
                #print(loss_decrease)
                
                
                
                
            elif int(prev_day_pnl) < 0 and int(curr_day_pnl) < 0 and int(prev_day_pnl) > int(curr_day_pnl): #prev_day_pnl = winning day & curr_day_pnl = Winning day & prev_day_pnl < curr_day_pnl
                
                curr_date = row[0]
                loss_decrease_trkr.append(curr_date)
                
                loss_decrease = -(int((prev_day_pnl))) + -(int(curr_day_pnl))
                loss_decrease_trkr.append(win_increase)
                
                loss_decrease_date_trkr_dict[curr_date] = loss_decrease
                #print(loss_decrease)                
                
                
            elif int(prev_day_pnl) < 0 and int(curr_day_pnl) < 0 and int(prev_day_pnl) < int(curr_day_pnl): #prev_day_pnl = winning day & curr_day_pnl = Winning day & prev_day_pnl > curr_day_pnl
                
                curr_date = row[0]
                loss_decrease_trkr.append(curr_date)
                
                loss_decrease = -(int((prev_day_pnl))) - -(int(curr_day_pnl))
                loss_decrease_trkr.append(loss_decrease)
                
                loss_decrease_date_trkr_dict[curr_date] = loss_decrease
                #print(loss_decrease)
            
            
            day_change = 'Losing Day. prev_day_pnl = ',prev_day_pnl,'curr_day_pnl = ',curr_day_pnl
            
            
            
        #id winning days
        elif int(curr_day_pnl) > 0: #winning day
            #win = str(row[0]) , int(curr_day_pnl)
            #print(win)
            
            
            
            if int(prev_day_pnl) < 0 and int(curr_day_pnl) > 0: #prev_day_pnl = losing day & curr_day_pnl = Winning day
                
                curr_date = row[0]
                win_increase_trkr.append(curr_date)
                
                win_increase = int(curr_day_pnl) - int((prev_day_pnl))
                win_increase_trkr.append(win_increase)
                
                win_increase_date_trkr_dict[curr_date] = win_increase
                #print(win_increase)
                
                
                
                
            elif int(prev_day_pnl) > 0 and int(curr_day_pnl) > 0 and int(prev_day_pnl) < int(curr_day_pnl): #prev_day_pnl = winning day & curr_day_pnl = Winning day & prev_day_pnl < curr_day_pnl
                
                curr_date = row[0]
                win_increase_trkr.append(curr_date)
                
                win_increase = (-int((prev_day_pnl))) + int(curr_day_pnl)
                win_increase_trkr.append(win_increase)
                
                win_increase_date_trkr_dict[curr_date] = win_increase
                #print(win_increase)                
                
                
            elif int(prev_day_pnl) > 0 and int(curr_day_pnl) > 0 and int(prev_day_pnl) > int(curr_day_pnl): #prev_day_pnl = winning day & curr_day_pnl = Winning day & prev_day_pnl > curr_day_pnl
                
                curr_date = row[0]
                win_increase_trkr.append(curr_date)
                
                win_increase = int((prev_day_pnl)) - int(curr_day_pnl)
                win_increase_trkr.append(win_increase)
                
                win_increase_date_trkr_dict[curr_date] = win_increase
                #print(win_increase)
            
            
            day_change = 'Winning Day. prev_day_pnl = ',prev_day_pnl,'curr_day_pnl = ',curr_day_pnl
        else:
            day_change = 'No Change in PNL. prev_day_pnl = ',prev_day_pnl,'curr_day_pnl = ',curr_day_pnl
    
            
    #print('win_increase_date_trkr_dict = ',win_increase_date_trkr_dict)
    #print('-' * 25)
    
    
    for i in loss_decrease_date_trkr_dict:
        loss_dates.append(i)
        loss_dates_index += 1
    #print('loss_dates = ',loss_dates)
    #print('-' * 10)
    #print('total loss_dates_index = ',loss_dates_index)
    #print('-' * 25)    
    
    for i in loss_decrease_date_trkr_dict.values():
        loss_decreases.append(i)
        loss_decreases_index += 1
        greatest_decrease = sorted(loss_decreases)[0]
        greatest_decrease_index = loss_decreases.index(greatest_decrease)
        greatest_decrease_date = loss_dates[greatest_decrease_index]
    #print('loss_decreases = ',loss_decreases)
    #print('-' * 10)
    #print('total loss_decreases_index = ',loss_decreases_index)
    #print('-' * 10)
    #print('sorted(loss_decreases)[-1] = ',sorted(loss_decreases)[-1])
    #print('-' * 25)
    
    
    #print('greatest_decrease = ',greatest_decrease)
    #print(greatest_decrease_index)
    
    for i in win_increase_date_trkr_dict:
        win_dates.append(i)
        win_dates_index += 1
    #print('win_dates = ',win_dates)
    #print('-' * 10)
    #print('total win_dates_index = ',win_dates_index)
    #print('-' * 25)    
    
    for i in win_increase_date_trkr_dict.values():
        win_increases.append(i)
        win_increases_index += 1
        greatest_increase = sorted(win_increases)[-1]
        greatest_increase_index = win_increases.index(greatest_increase)
        greatest_increase_date = win_dates[greatest_increase_index]
    #print('win_increases = ',win_increases)
    #print('-' * 10)
    #print('total win_increases_index = ',win_increases_index)
    #print('-' * 10)
    #print('sorted(win_increases)[-1] = ',sorted(win_increases)[-1])
    #print('-' * 25)
    
    
    #print('greatest_increase = ',greatest_increase)
    #print(greatest_increase_index)
#print(pnl_trkr)     
for i in pnl_trkr:
    #print('for i in pnl_trkr:','i = ',i ,'prev_price = ',prev_price,'curr_price = ',curr_price)
    if prev_price == None and curr_price == None:
        #print('if prev_price == None and curr_price == None:','i = ',i ,'prev_price = ',prev_price,'curr_price = ',curr_price)
        prev_price = int(i)
        curr_price = int(i)
    elif prev_price == curr_price and curr_price != int(i):
        #print('elif prev_price == curr_price and curr_price != int(i):','i = ',i ,'prev_price = ',prev_price,'curr_price = ',curr_price)
        prev_price = curr_price 
        curr_price = int(i)
    elif prev_price != curr_price and curr_price != int(i):
        #print('elif prev_price != curr_price and curr_price != int(i):','i = ',i ,'prev_price = ',prev_price,'curr_price = ',curr_price)
        prev_price = curr_price 
        curr_price = int(i)
        
        if prev_price < 0 and curr_price < 0 and prev_price < curr_price: # 
            #print('elif prev_price < 0 and curr_price < 0 and prev_price < curr_price: ,-,-', 'i = ',i ,'prev_price = ',prev_price,'curr_price = ',curr_price)
            change = abs(((prev_price)-(curr_price)))
            change_trkr.append(change)
        elif prev_price < 0 and curr_price < 0 and prev_price > curr_price: # 
            #print('elif prev_price < 0 and curr_price < 0 and prev_price > curr_price:,-,-', 'i = ',i ,'prev_price = ',prev_price,'curr_price = ',curr_price)
            change = abs(((prev_price)-(curr_price)))
            change_trkr.append(change)   

        elif prev_price < 0 and curr_price > 0 and prev_price < curr_price: # 
            #print('elif prev_price < 0 and curr_price < 0 and prev_price < curr_price: ,-,-', 'i = ',i ,'prev_price = ',prev_price,'curr_price = ',curr_price)
            change = abs(((prev_price)-(curr_price)))
            change_trkr.append(change)
        elif prev_price < 0 and curr_price > 0 and prev_price > curr_price: # 
            #print('elif prev_price < 0 and curr_price < 0 and prev_price > curr_price:,-,-', 'i = ',i ,'prev_price = ',prev_price,'curr_price = ',curr_price)
            change = abs(((prev_price)-(curr_price)))
            change_trkr.append(change)   

        elif prev_price > 0 and curr_price > 0 and prev_price < curr_price: # 
            #print('elif prev_price < 0 and curr_price < 0 and prev_price < curr_price: ,-,-', 'i = ',i ,'prev_price = ',prev_price,'curr_price = ',curr_price)
            change = abs(((prev_price)-(curr_price)))
            change_trkr.append(change)
        elif prev_price > 0 and curr_price > 0 and prev_price > curr_price: # 
            #print('elif prev_price < 0 and curr_price < 0 and prev_price > curr_price:,-,-', 'i = ',i ,'prev_price = ',prev_price,'curr_price = ',curr_price)
            change = abs(((prev_price)-(curr_price)))
            change_trkr.append(change)   

        elif prev_price > 0 and curr_price < 0 and prev_price < curr_price: # 
            #print('elif prev_price < 0 and curr_price < 0 and prev_price < curr_price: ,-,-', 'i = ',i ,'prev_price = ',prev_price,'curr_price = ',curr_price)
            change = abs(((prev_price)-(curr_price)))
            change_trkr.append(change)
        elif prev_price > 0 and curr_price < 0 and prev_price > curr_price: # 
            #print('elif prev_price < 0 and curr_price < 0 and prev_price > curr_price:,-,-', 'i = ',i ,'prev_price = ',prev_price,'curr_price = ',curr_price)
            change = abs(((prev_price)-(curr_price)))
            change_trkr.append(change)   
change_calc = 0            
#for i in change_trkr:
#    change_calc = change_calc + i
#avg_chg = change_calc / total_mths
        
        
avg_chg = (float(pnl_trkr[-1]) - float(pnl_trkr[0])) / float(total_mths) - 1 



print('Financial Analysis')
print('-'*25)

print(f'Total Months: {total_mths}')
print(f'Total: ${total}')
print(f'Average Change: {round(avg_chg,2)}')
print(f'Greatest Increase in Profits: {greatest_increase_date} (${greatest_increase})')
print(f'Greatest Decrease in Profits: {greatest_decrease_date} (${greatest_decrease})')
# Out:
# Financial Analysis
# -------------------------
# Total Months: 86
# Total: $38382578
# Average Change: -2289.2
# Greatest Increase in Profits: Feb-2012 ($1926159)
# Greatest Decrease in Profits: Sep-2013 ($-2196167)
